# %% [markdown]
# <a href="https://colab.research.google.com/github/ranjushreee88-sys/Linear-Regression/blob/main/Copy_of_Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python matplotlib --quiet

# %%
import cv2
from matplotlib import pyplot as plt
from google.colab import files

# %%
image_files = '/content/nature.jpg'
image = cv2.imread(image_files)

# %%
image = cv2.imread(image_files)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)
plt.show()

# %%
# !wget -O hear_face.xml
