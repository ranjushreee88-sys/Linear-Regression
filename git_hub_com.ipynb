# %% [markdown]
# <a href="https://colab.research.google.com/github/ranjushreee88-sys/Linear-Regression/blob/main/git_hub_com.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

df = pd.read_csv("/content/home-rental.csv")
print("First 5 rowsof dataset")
print(df.head())

x=df[["size"]]
y=df[["rent_amount"]]


x_train,x_test,y_train,y_test=train_test_split(
    x,y,test_size=0.2, random_state = 42
)

model = LinearRegression()
model.fit(x_train,y_train)

y_pred = model.predict(x_test)

mse = mean_squared_error(y_test,y_pred)
print("Mean Squared Error:",mse)

plt.scatter(x, y, color = "blue")
plt.plot(x, model.predict(x), color = "red")
plt.xlabel("Area(sq.ft)")
plt.ylabel("Price($10000)")
plt.title("Linear Regression Example")
plt.show()
# Out:
# First 5 rowsof dataset
#    property_id            address  postal_code  size  bedrooms  rent_amount
# 0            1     123 Oak Street        12345  1200         2         1680
# 1            2    456 Pine Avenue        23456  1800         3         2590
# 2            3    789 Maple Drive        34567   950         1         1520
# 3            4  321 Elm Boulevard        45678  2200         4         3240
# 4            5     654 Cedar Lane        56789  1450         2         2030
# Mean Squared Error: 3781.01129644514

# %% [markdown]
# # New Section

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering

df = pd.read_csv("/content/Mall_Customers.csv")

# Corrected column names based on the DataFrame's actual structure
x = df[["Annual_Income_(k$)", "Spending_Score"]]

agg_model = AgglomerativeClustering(n_clusters = 3)

df['cluster'] = agg_model.fit_predict(x)

# Fixed: Changed square brackets to parentheses for the plt.scatter function call
plt.scatter(x['Annual_Income_(k$)'], x['Spending_Score'], c=df['cluster'], cmap = 'rainbow')
plt.xlabel("Annual Income (k$)")
plt.ylabel("Spending Score")
plt.title("Agglomerative Clustering")
plt.show()

df.to_csv("agglo_clustered_data.csv", index = False)
print("Agglomerative clustered dataset saved as 'agglo_clustered_data.csv' ")
# Out:
# Agglomerative clustered dataset saved as 'agglo_clustered_data.csv'
